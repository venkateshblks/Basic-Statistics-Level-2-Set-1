# %% [markdown]
# # Set 1_Descriptive statistics+Probability
#
# ### 1. Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2
#
# Name of company	Measure X
# Allied Signal	24.23%
# Bankers Trust	25.53%
# General Mills	25.41%
# ITT Industries	24.14%
# J.P.Morgan & Co.	29.62%
# Lehman Brothers	28.25%
# Marriott	25.81%
# MCI	24.39%
# Merrill Lynch	40.26%
# Microsoft	32.95%
# Morgan Stanley	91.36%
# Sun Microsystems	25.99%
# Travelers	39.42%
# US Airways	26.71%
# Warner-Lambert	35.00%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {
    'Company': ['Allied Signal', 'Bankers Trust', 'General Mills', 'ITT Industries', 'J.P.Morgan & Co.',
                'Lehman Brothers', 'Marriott', 'MCI', 'Merrill Lynch', 'Microsoft', 'Morgan Stanley',
                'Sun Microsystems', 'Travelers', 'US Airways', 'Warner-Lambert'],
    'Measure X': [24.23, 25.53, 25.41, 24.14, 29.62, 28.25, 25.81, 24.39, 40.26, 32.95, 91.36, 25.99, 39.42, 26.71, 35.00]
}
df = pd.DataFrame(data)
plt.bar(df['Company'], df['Measure X'])
plt.xticks(rotation=90)
plt.show()
sns.boxplot(df)
plt.show()

# %% [markdown]
# #### From the above graphs, we can conclude that the outlier is Morgan Stanley with a value of 91.36

# %%
q1=df["Measure X"].quantile(0.25)
q2=df["Measure X"].quantile(0.75)
iqr=q2-q1
lb=q1-1.5*iqr
ub=q2+1.5*iqr
df[(df["Measure X"]<lb) | (df['Measure X']>ub)]
#The outliers are
# Out:
#            Company  Measure X
# 10  Morgan Stanley      91.36

# %%
print('mean ',df["Measure X"].mean())
print("standard devaition ",df['Measure X'].std())
print("variance ",df['Measure X'].var())
# Out:
# mean  33.27133333333333
# standard devaition  16.945400921222028
# variance  287.1466123809524
